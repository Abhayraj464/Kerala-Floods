# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import missingno as msn
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
# Out:
# D:\Software\Anaconda\lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
data = pd.read_csv("C:/Users/Windows10/Downloads/kerala.csv.xls")
data
# Out:
#     SUBDIVISION  YEAR   JAN   FEB   MAR    APR    MAY     JUN     JUL     AUG  \
# 0        KERALA  1901  28.7  44.7  51.6  160.0  174.7   824.6   743.0   357.5
# 1        KERALA  1902   6.7   2.6  57.3   83.9  134.5   390.9  1205.0   315.8
# 2        KERALA  1903   3.2  18.6   3.1   83.6  249.7   558.6  1022.5   420.2
# 3        KERALA  1904  23.7   3.0  32.2   71.5  235.7  1098.2   725.5   351.8
# 4        KERALA  1905   1.2  22.3   9.4  105.9  263.3   850.2   520.5   293.6
# ..          ...   ...   ...   ...   ...    ...    ...     ...     ...     ...
# 113      KERALA  2014   4.6  10.3  17.9   95.7  251.0   454.4   677.8   733.9
# 114      KERALA  2015   3.1   5.8  50.1  214.1  201.8   563.6   406.0   252.2
# 115      KERALA  2016   2.4   3.8  35.9  143.0  186.4   522.2   412.3   325.5
# 116     KERALA   2017   1.9   6.8   8.9   43.6  173.5   498.5   319.6   531.8
# 117      KERALA  2018  29.1  52.1  48.6  116.4  183.8   625.4  1048.5  1398.9
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118 entries, 0 to 117
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   SUBDIVISION       118 non-null    object
#  1   YEAR              118 non-null    int64
#  2   JAN               118 non-null    float64
#  3   FEB               118 non-null    float64
#  4   MAR               118 non-null    float64
#  5   APR               118 non-null    float64
#  6   MAY               118 non-null    float64
#  7   JUN               118 non-null    float64
#  8   JUL               118 non-null    float64
#  9   AUG               118 non-null    float64
#  10  SEP               118 non-null    float64
#  11  OCT               118 non-null    float64
#  12  NOV               118 non-null    float64
#  13  DEC               118 non-null    float64
#  14   ANNUAL RAINFALL  118 non-null    float64
#  15  FLOODS            118 non-null    object
# ...

# %%
data.describe()
# Out:
#               YEAR         JAN         FEB         MAR         APR  \
# count   118.000000  118.000000  118.000000  118.000000  118.000000
# mean   1959.500000   12.218644   15.633898   36.670339  110.330508
# std      34.207699   15.473766   16.406290   30.063862   44.633452
# min    1901.000000    0.000000    0.000000    0.100000   13.100000
# 25%    1930.250000    2.175000    4.700000   18.100000   74.350000
# 50%    1959.500000    5.800000    8.350000   28.400000  110.400000
# 75%    1988.750000   18.175000   21.400000   49.825000  136.450000
# max    2018.000000   83.500000   79.000000  217.200000  238.000000
#
#               MAY          JUN          JUL          AUG         SEP  \
# count  118.000000   118.000000   118.000000   118.000000  118.000000
# mean   228.644915   651.617797   698.220339   430.369492  246.207627
# std    147.548778   186.181363   228.988966   181.980463  121.901131
# min     53.400000   196.800000   167.500000   178.600000   41.300000
# ...

# %%
msn.matrix(data)
# Out:
# <Axes: >

# %%
data.isnull().sum()
# Out:
# SUBDIVISION         0
# YEAR                0
# JAN                 0
# FEB                 0
# MAR                 0
# APR                 0
# MAY                 0
# JUN                 0
# JUL                 0
# AUG                 0
# SEP                 0
# OCT                 0
# NOV                 0
# DEC                 0
#  ANNUAL RAINFALL    0
# FLOODS              0
# dtype: int64

# %%
duplicate = data[data.duplicated()]
duplicate
# Out:
# Empty DataFrame
# Columns: [SUBDIVISION, YEAR, JAN, FEB, MAR, APR, MAY, JUN, JUL, AUG, SEP, OCT, NOV, DEC,  ANNUAL RAINFALL, FLOODS]
# Index: []

# %% [markdown]
# ## Take Away
#
# #### <b><font color = green>1. Here data set is clean which have no null or duplicate rows.</font>

# %%
data.columns
# Out:
# Index(['SUBDIVISION', 'YEAR', 'JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL',
#        'AUG', 'SEP', 'OCT', 'NOV', 'DEC', ' ANNUAL RAINFALL', 'FLOODS'],
#       dtype='object')

# %%
data.rename(columns={' ANNUAL RAINFALL':'ANNUAL RAINFALL'},inplace= True)

# %%
 data.columns
# Out:
# Index(['SUBDIVISION', 'YEAR', 'JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL',
#        'AUG', 'SEP', 'OCT', 'NOV', 'DEC', 'ANNUAL RAINFALL', 'FLOODS'],
#       dtype='object')

# %%
cols = ['YEAR', 'JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL','AUG', 'SEP', 'OCT', 'NOV', 'DEC', 'ANNUAL RAINFALL']

# %%
def box_plot(df,column):
    for col in column:
        plt.figure(figsize=(8,6))
        sns.boxplot(df[col])
        plt.title(col)
        plt.show()

# %%
box_plot(data,cols)

# %%
def hsit_plot(df,column):
    for col in column:
        plt.figure(figsize=(10,6))
        sns.histplot(df[col],kde=True, color = "green")
        plt.title(col)
        plt.show()

# %%
hsit_plot(data,cols)

# %% [markdown]
# ## Take Away
#
# 1. Outliers are present in columns except June, September, November and Year. But these outliers need not to manipulate, because these outlier data are relavent to the final outcome result.
#
# 2. Most of the columns are right skewed and no left skewd columns.

# %%
flood = data['FLOODS'].value_counts()
fld = pd.DataFrame(flood)
fld
# Out:
#         count
# FLOODS
# YES        60
# NO         58

# %%
fld.reset_index(inplace=True)

# %%
fld.columns
# Out:
# Index(['FLOODS', 'count'], dtype='object')

# %%
plt.figure(figsize=(8,4))
sns.catplot(fld, x = 'FLOODS', y = 'count')
plt.title("Count of Floods ")
plt.show()

# %% [markdown]
# ### <b> Flood Ocuured 60 times in Kerala along the years.

# %%
data.columns
# Out:
# Index(['SUBDIVISION', 'YEAR', 'JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL',
#        'AUG', 'SEP', 'OCT', 'NOV', 'DEC', 'ANNUAL RAINFALL', 'FLOODS'],
#       dtype='object')

# %%
data.drop(columns= 'SUBDIVISION',inplace = True)

# %%
plt.figure(figsize=(10,5))
plt.plot('YEAR', 'ANNUAL RAINFALL', data=data, marker='*', linestyle='--', color='m')
plt.grid(axis ='both',linestyle='-', color='g' )
plt.title('Annual Rainfall per Year', fontdict={'fontsize': 18})
plt.xlabel('YEAR', fontdict={'fontsize': 14})
plt.show()

# %%
grp_fld = data.groupby('FLOODS')

# %%
data['ANNUAL RAINFALL'].describe()
# Out:
# count     118.000000
# mean     2925.405085
# std       452.169407
# min      2068.800000
# 25%      2613.525000
# 50%      2934.300000
# 75%      3170.400000
# max      4473.000000
# Name: ANNUAL RAINFALL, dtype: float64

# %%
flds = grp_fld['ANNUAL RAINFALL'].get_group('YES')
flds.describe()
# Out:
# count      60.000000
# mean     3269.028333
# std       332.461425
# min      2923.100000
# 25%      3042.275000
# 50%      3164.100000
# 75%      3395.275000
# max      4473.000000
# Name: ANNUAL RAINFALL, dtype: float64

# %%
no_flds = grp_fld['ANNUAL RAINFALL'].get_group('NO')
no_flds.describe()
# Out:
# count      58.000000
# mean     2569.932759
# std       228.904878
# min      2068.800000
# 25%      2412.525000
# 50%      2610.400000
# 75%      2736.225000
# max      2931.100000
# Name: ANNUAL RAINFALL, dtype: float64

# %%
data[data['ANNUAL RAINFALL'] == 4473.00]
# Out:
#      YEAR   JAN   FEB   MAR    APR    MAY    JUN     JUL     AUG    SEP  \
# 117  2018  29.1  52.1  48.6  116.4  183.8  625.4  1048.5  1398.9  423.6
#
#        OCT    NOV   DEC  ANNUAL RAINFALL FLOODS
# 117  356.1  125.4  65.1           4473.0    YES

# %% [markdown]
# ## Take Away
#
# 1. Maximum annual rainfall occured is 4473.0 and maximum annual rainfall which caused flood is also 4473.0 which is in the year 2018.
# 2. Flood occured when annual rainfall is above  2900 and below 2900 no flood occured.

# %% [markdown]
# ### Analyze based on season in kerala

# %%
data.columns
# Out:
# Index(['YEAR', 'JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL', 'AUG', 'SEP',
#        'OCT', 'NOV', 'DEC', 'ANNUAL RAINFALL', 'FLOODS'],
#       dtype='object')

# %% [markdown]
# ### Monsoon Season

# %%
monsoon = data[['JUN', 'JUL','AUG', 'SEP']]
monsoon
# Out:
#         JUN     JUL     AUG    SEP
# 0     824.6   743.0   357.5  197.7
# 1     390.9  1205.0   315.8  491.6
# 2     558.6  1022.5   420.2  341.8
# 3    1098.2   725.5   351.8  222.7
# 4     850.2   520.5   293.6  217.2
# ..      ...     ...     ...    ...
# 113   454.4   677.8   733.9  298.8
# 114   563.6   406.0   252.2  292.9
# 115   522.2   412.3   325.5  173.2
# 116   498.5   319.6   531.8  209.5
# 117   625.4  1048.5  1398.9  423.6
#
# [118 rows x 4 columns]

# %% [markdown]
# ### Summer Season

# %%
summer = data[[ 'MAR', 'APR', 'MAY']]
summer
# Out:
#       MAR    APR    MAY
# 0    51.6  160.0  174.7
# 1    57.3   83.9  134.5
# 2     3.1   83.6  249.7
# 3    32.2   71.5  235.7
# 4     9.4  105.9  263.3
# ..    ...    ...    ...
# 113  17.9   95.7  251.0
# 114  50.1  214.1  201.8
# 115  35.9  143.0  186.4
# 116   8.9   43.6  173.5
# 117  48.6  116.4  183.8
#
# [118 rows x 3 columns]

# %% [markdown]
# ### Winter Season

# %%
winter = data[[ 'DEC','JAN', 'FEB']]
winter
# Out:
#        DEC   JAN   FEB
# 0     48.4  28.7  44.7
# 1    121.5   6.7   2.6
# 2     59.0   3.2  18.6
# 3      3.3  23.7   3.0
# 4      0.2   1.2  22.3
# ..     ...   ...   ...
# 113   47.2   4.6  10.3
# 114   79.4   3.1   5.8
# 115   23.6   2.4   3.8
# 116   38.1   1.9   6.8
# 117   65.1  29.1  52.1
#
# [118 rows x 3 columns]

# %% [markdown]
# ### Post Monsoon Season

# %%
Post_monsoon = data[[ 'OCT', 'NOV']]
Post_monsoon
# Out:
#        OCT    NOV
# 0    266.9  350.8
# 1    358.4  158.3
# 2    354.1  157.0
# 3    328.1   33.9
# 4    383.5   74.4
# ..     ...    ...
# 113  355.5   99.5
# 114  308.1  223.6
# 115  225.9  125.4
# 116  192.4   92.5
# 117  356.1  125.4
#
# [118 rows x 2 columns]

# %%
def season(df,column):
    for i in column:
        plt.figure(figsize=(10,8))
        sns.lineplot(df, x ='YEAR', y =i,hue = 'FLOODS',style = 'FLOODS',linestyle='dotted',marker='*', markerfacecolor='limegreen',
                     markersize=10, palette=['blue','yellowgreen'] )
        plt.title(i, fontdict={'fontsize': 18})
        plt.xlabel('YEAR', fontdict={'fontsize': 14})
        plt.grid()
        plt.legend(loc='upper right')
        plt.show()

# %%
season(data,monsoon)

# %%
season(data,summer)

# %%
season(data,winter)

# %%
season(data,Post_monsoon)

# %%
new = data.replace( {'FLOODS':{'YES':1, 'NO':0}})

# %%
new
# Out:
#      YEAR   JAN   FEB   MAR    APR    MAY     JUN     JUL     AUG    SEP  \
# 0    1901  28.7  44.7  51.6  160.0  174.7   824.6   743.0   357.5  197.7
# 1    1902   6.7   2.6  57.3   83.9  134.5   390.9  1205.0   315.8  491.6
# 2    1903   3.2  18.6   3.1   83.6  249.7   558.6  1022.5   420.2  341.8
# 3    1904  23.7   3.0  32.2   71.5  235.7  1098.2   725.5   351.8  222.7
# 4    1905   1.2  22.3   9.4  105.9  263.3   850.2   520.5   293.6  217.2
# ..    ...   ...   ...   ...    ...    ...     ...     ...     ...    ...
# 113  2014   4.6  10.3  17.9   95.7  251.0   454.4   677.8   733.9  298.8
# 114  2015   3.1   5.8  50.1  214.1  201.8   563.6   406.0   252.2  292.9
# 115  2016   2.4   3.8  35.9  143.0  186.4   522.2   412.3   325.5  173.2
# 116  2017   1.9   6.8   8.9   43.6  173.5   498.5   319.6   531.8  209.5
# 117  2018  29.1  52.1  48.6  116.4  183.8   625.4  1048.5  1398.9  423.6
#
#        OCT    NOV    DEC  ANNUAL RAINFALL  FLOODS
# ...

# %%
new['FLOODS'].value_counts()
# Out:
# FLOODS
# 1    60
# 0    58
# Name: count, dtype: int64

# %%
core = new.corr()

# %%
core
# Out:
#                      YEAR       JAN       FEB       MAR       APR       MAY  \
# YEAR             1.000000 -0.225531  0.003879 -0.012842  0.086865 -0.059661
# JAN             -0.225531  1.000000  0.019613  0.078626  0.034807  0.071420
# FEB              0.003879  0.019613  1.000000  0.245375  0.123706 -0.083500
# MAR             -0.012842  0.078626  0.245375  1.000000  0.074014 -0.102961
# APR              0.086865  0.034807  0.123706  0.074014  1.000000 -0.114566
# MAY             -0.059661  0.071420 -0.083500 -0.102961 -0.114566  1.000000
# JUN             -0.174938  0.189375  0.054114  0.019000  0.072990  0.001235
# JUL             -0.223403  0.034423  0.005789  0.018330  0.014977 -0.046518
# AUG              0.044173  0.008677  0.023259  0.042411 -0.047842 -0.124412
# SEP              0.107655 -0.113502  0.066317  0.143850  0.012928  0.116860
# OCT             -0.030223 -0.035044  0.053133 -0.023066  0.113172  0.197102
# ...

# %%
plt.figure(figsize=(14,8))
sns.heatmap(core,cmap='coolwarm',annot=True,fmt='.2%')
plt.title('Correlation Table', fontdict={'fontsize': 18})
plt.show()

# %% [markdown]
# - While checking correlation:
#     - More relation is seen in the months of June and July when comparing annual rainfall and flood occurrences.
#     - We can check the probability or chance of flooding in each month according to the rainfall.
#
# - Winter season:
#     - Shows less relation to the annual rainfall and floods.
#     - Therefore, the chance of flooding is less during this season.

# %%
rainfall = new[['YEAR','JUN', 'JUL','FLOODS']]
rainfall
# Out:
#      YEAR     JUN     JUL  FLOODS
# 0    1901   824.6   743.0       1
# 1    1902   390.9  1205.0       1
# 2    1903   558.6  1022.5       1
# 3    1904  1098.2   725.5       1
# 4    1905   850.2   520.5       0
# ..    ...     ...     ...     ...
# 113  2014   454.4   677.8       1
# 114  2015   563.6   406.0       0
# 115  2016   522.2   412.3       0
# 116  2017   498.5   319.6       0
# 117  2018   625.4  1048.5       1
#
# [118 rows x 4 columns]

# %%
rainfall .describe()
# Out:
#               YEAR          JUN          JUL      FLOODS
# count   118.000000   118.000000   118.000000  118.000000
# mean   1959.500000   651.617797   698.220339    0.508475
# std      34.207699   186.181363   228.988966    0.502060
# min    1901.000000   196.800000   167.500000    0.000000
# 25%    1930.250000   535.550000   533.200000    0.000000
# 50%    1959.500000   625.600000   691.650000    1.000000
# 75%    1988.750000   786.975000   832.425000    1.000000
# max    2018.000000  1098.200000  1526.500000    1.000000

# %%
rainfall.dtypes
# Out:
# YEAR        int64
# JUN       float64
# JUL       float64
# FLOODS      int64
# dtype: object

# %% [markdown]
# <b> We take threshold rainfall which is 500mm rained more in these month.

# %%
rainfall['JUN>500'] = (rainfall['JUN']>500).astype('int')
rainfall['JUL>500'] = (rainfall['JUL']>500).astype('int')
# Out:
# C:\Users\Windows10\AppData\Local\Temp\ipykernel_6228\2168918590.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rainfall['JUN>500'] = (rainfall['JUN']>500).astype('int')
# C:\Users\Windows10\AppData\Local\Temp\ipykernel_6228\2168918590.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rainfall['JUL>500'] = (rainfall['JUL']>500).astype('int')

# %%
new_rainfall = rainfall.loc[:,['YEAR','JUN>500','JUL>500','FLOODS']]

# %%
new_rainfall
# Out:
#      YEAR  JUN>500  JUL>500  FLOODS
# 0    1901        1        1       1
# 1    1902        0        1       1
# 2    1903        1        1       1
# 3    1904        1        1       1
# 4    1905        1        1       0
# ..    ...      ...      ...     ...
# 113  2014        0        1       1
# 114  2015        1        0       0
# 115  2016        1        0       0
# 116  2017        0        0       0
# 117  2018        1        1       1
#
# [118 rows x 4 columns]

# %% [markdown]
# P(A) = Probability of Flooding
#
# P(B) = Probaility of having more than 500 mm rain in June
#
# p(AnB) = Probabiity of flooding and having more than 500mm rain in June
#
# P(A|B) = Probabiity of flooding given it rained more than 500 mm in June

# %%
pd.crosstab(new_rainfall["JUN>500"],new_rainfall["FLOODS"],margins=True)
# Out:
# FLOODS    0   1  All
# JUN>500
# 0        19   6   25
# 1        39  54   93
# All      58  60  118

# %%
#P(A) =60/118
60/118
# Out:
# 0.5084745762711864

# %%
#P(B) = 93/118
93/118
# Out:
# 0.788135593220339

# %%
#p_A_and_B = rainfall[(rainfall['JUN>500'] == 1) & (new_rainfall["FLOODS"] == 1)].shape[0] /rainfall.shape[0]
#p_A_and_B = 54/118
54/118
# Out:
# 0.4576271186440678

# %%
#P(A|B) = p(AnB) / P(B)
0.4576271186440678/0.788135593220339
# Out:
# 0.5806451612903226

# %% [markdown]
# <b> Percentage of occuring flood in June, if the rainfaill is greater than 500mm is 58%

# %% [markdown]
# P(A) = Probability of Flooding
#
# P(B) = Probaility of having more than 500 mm rain in July
#
# p(AnB) = Probabiity of flooding and having more than 500mm rain in July
#
# P(A|B) = Probabiity of flooding given it rained more than 500 mm in July

# %%
pd.crosstab(new_rainfall['JUL>500'],new_rainfall["FLOODS"],margins=True)
# Out:
# FLOODS    0   1  All
# JUL>500
# 0        19   3   22
# 1        39  57   96
# All      58  60  118

# %%
#P(A) =60/118
60/118
# Out:
# 0.5084745762711864

# %%
#P(B) = 96/118
96/118
# Out:
# 0.8135593220338984

# %%
#p_A_and_B = 57/118
57/118
# Out:
# 0.4830508474576271

# %%
#P(A|B) = p(AnB) / P(B)
0.4830508474576271/0.8135593220338984
# Out:
# 0.59375

# %% [markdown]
# <b> Percentage of occuring flood in July, if the rainfaill is greater than 500mm is 59%

# %%
new.columns
# Out:
# Index(['YEAR', 'JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL', 'AUG', 'SEP',
#        'OCT', 'NOV', 'DEC', 'ANNUAL RAINFALL', 'FLOODS'],
#       dtype='object')

# %%
x = new.drop(columns=['FLOODS'])

# %%
y = new['FLOODS']
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 113    1
# 114    0
# 115    0
# 116    0
# 117    1
# Name: FLOODS, Length: 118, dtype: int64

# %% [markdown]
# ### Model creation

# %% [markdown]
# #### Fit the scaler to the data and transform the data

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
x_scaled = scaler.fit_transform(x)

# %%
x_scaled.shape
# Out:
# (118, 14)

# %% [markdown]
# #### split the data into training and testing sets

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x_scaled,y,train_size= 0.3, random_state=42)

# %% [markdown]
# #### Train the model

# %%
from sklearn.linear_model import LogisticRegression

# %%
fd = LogisticRegression()

# %%
fd.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# #### Predict the target variable on the test data

# %%
y_pred = fd.predict(x_test)
y_pred.shape
# Out:
# (83,)

# %%
y_test.shape
# Out:
# (83,)

# %% [markdown]
# #### Evaluating the model

# %%
from sklearn.metrics import accuracy_score, classification_report,precision_score,recall_score,f1_score,confusion_matrix

# %%
accuracy = accuracy_score(y_test,y_pred)
print(f"Accuracy : {accuracy: .2f}")
# Out:
# Accuracy :  0.90

# %%
classification = classification_report(y_test,y_pred)
print(classification)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.83      0.90        42
#            1       0.85      0.98      0.91        41
#
#     accuracy                           0.90        83
#    macro avg       0.91      0.90      0.90        83
# weighted avg       0.91      0.90      0.90        83

# %%
matrix = confusion_matrix(y_test,y_pred)
matrix
# Out:
# array([[35,  7],
#        [ 1, 40]], dtype=int64)

# %%
plt.figure(figsize=(8,4))
sns.heatmap(matrix, annot =True)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# %% [markdown]
# - Classification Report:
#
#     - Class 0 (No Floods):
#         - Precision: 97% (out of all predicted "No Floods," 97% were correct)
#         - Recall: 83% (out of all actual "No Floods," 83% were correctly identified)
#         - F1 Score: 90%
#     - Class 1 (Floods):
#         - Precision: 85% (out of all predicted "Floods," 85% were correct)
#         - Recall: 98% (out of all actual "Floods," 98% were correctly identified)
#         - F1 Score: 91%
#
#
# <b>Overall:
# The model performs well across both classes, with a balanced precision, recall, and F1 score.
# Confusion Matrix:

# %% [markdown]
# - The confusion matrix shows:
#     - True Positives (TP): 40 instances of Class 1 (Floods) were correctly identified.
#     - True Negatives (TN): 35 instances of Class 0 (No Floods) were correctly identified.
#     - False Positives (FP): 7 instances of Class 0 (No Floods) were incorrectly classified as Floods.
#     - False Negatives (FN): 1 instance of Class 1 (Floods) was incorrectly classified as No Floods.
